# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("D:\DataScience\August\datascience projects\Breast+cancer\data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df=df.drop(['Unnamed: 32'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df['diagnosis']=df.diagnosis.map({'B':0,'M':1})

# %%
df.diagnosis.value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
plt.figure(figsize=(10,8))
sns.countplot(df.diagnosis)
plt.xlabel('diagnosis')
plt.ylabel('count')
plt.title('diagnosis 0 & 1')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['diagnosis'],axis=1)
y=df.diagnosis.values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %%
x_train.shape
# Out:
# (455, 31)

# %%
y_train.shape
# Out:
# (455,)

# %%
x_test.shape
# Out:
# (114, 31)

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
print('Test Accuracy: {:.2f}%'.format(lr.score(x_test,y_test)*100))
# Out:
# Test Accuracy: 92.98%

# %%
from sklearn.metrics import accuracy_score
y_pred_lr=lr.predict(x_test)
print('Accuracy of model: {:.2f}%'.format(accuracy_score(y_test,y_pred_lr)*100))
# Out:
# Accuracy of model: 92.98%

# %%
#SVC
from sklearn.svm import SVC
svc=SVC(random_state=1)
svc.fit(x_train,y_train)
print('Test Accuracy: {:.2f}%'.format(svc.score(x_test,y_test)*100))
# Out:
# Test Accuracy: 57.89%

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB
gb=GaussianNB()
gb.fit(x_train,y_train)
print('Test Accuracy: {:.2f}%'.format(gb.score(x_test,y_test)*100))
# Out:
# Test Accuracy: 57.02%

# %%
#Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=100,random_state=5)
rf.fit(x_train,y_train)
print('Test Accuracy:{:.2f}%'.format(rf.score(x_test,y_test)*100))
# Out:
# Test Accuracy:97.37%

# %%
import xgboost
xg=xgboost.XGBClassifier()
xg.fit(x_train,y_train)
print('Test Accuracy: {:.2f}%'.format(xg.score(x_test,y_test)*100))
# Out:
# Test Accuracy: 96.49%

# %%
#Logistic model Accuracy: 92.98%
#SVC model Accuracy: 57.89%
#Naive Bayes model Accuracy: 57.02%
#Random Forest Classifier Accuracy: 97.37%
#xgboost model Accuracy: 96.49%
